# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
#read, grayscale
img = cv2.imread('image3.jpg')
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
filters = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edge = cv2.Canny(filters, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edge, cv2.COLOR_BGR2RGB))

# %%
#Countours
keypoints = cv2.findContours(edge.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
coor = None
for i in contours:
    approx = cv2.approxPolyDP(i, 10, True)
    if len(approx) == 4:
        coor = approx
        break

# %%
coor
# Out:
# array([[[263, 334]],
#
#        [[264, 363]],
#
#        [[369, 362]],
#
#        [[366, 333]]], dtype=int32)

# %%
#Mask
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [coor], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
#OCR
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[0, 2], [107, 2], [107, 31], [0, 31]], 'EBJY. 982]', 0.3741937983327902)]

# %%
print(result)
# Out:
# [([[0, 2], [107, 2], [107, 31], [0, 31]], 'EBJY. 982]', 0.3741937983327902)]

# %%
#Result
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11068/1571596900.py in <module>
#       1 #Result
# ----> 2 text = result[0,4]
#       3 font = cv2.FONT_HERSHEY_SIMPLEX
#       4 res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
#       5 res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
#
# TypeError: list indices must be integers or slices, not tuple
